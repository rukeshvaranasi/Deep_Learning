# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Deep_Learning\Assignments & Projects\WineQuality_Project\winequality.csv")
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.duplicated().sum()
# Out:
# 1168

# %%
# dropping of duplicates
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5329 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  5329 non-null   object
#  1   fixed acidity         5319 non-null   float64
#  2   volatile acidity      5321 non-null   float64
#  3   citric acid           5326 non-null   float64
#  4   residual sugar        5327 non-null   float64
#  5   chlorides             5327 non-null   float64
#  6   free sulfur dioxide   5329 non-null   float64
#  7   total sulfur dioxide  5329 non-null   float64
#  8   density               5329 non-null   float64
#  9   pH                    5320 non-null   float64
#  10  sulphates             5325 non-null   float64
#  11  alcohol               5329 non-null   float64
#  12  quality               5329 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 582.9+ KB

# %% [markdown]
# ### filling null values

# %%
df["fixed acidity"].mode()
# Out:
# 0    6.8
# Name: fixed acidity, dtype: float64

# %%
df[df["fixed acidity"].isna()]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 17    white            NaN             0.660         0.48             1.2
# 174   white            NaN             0.270         0.31            17.7
# 249   white            NaN             0.410         0.14            10.4
# 267   white            NaN             0.580         0.07             6.9
# 368   white            NaN             0.290         0.48             2.3
# 518   white            NaN             0.130         0.28             1.9
# 1079  white            NaN               NaN         0.29             6.2
# 2902  white            NaN             0.360         0.14             8.9
# 6428    red            NaN             0.440         0.09             2.2
# 6429    red            NaN             0.705         0.10             2.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 17        0.029                 29.0                  75.0  0.98920  3.33
# ...

# %%
# filling nans in fixed acidity
df["fixed acidity"]=df["fixed acidity"].fillna(df["fixed acidity"].mode()[0])

# %%
df["volatile acidity"].mode()
# Out:
# 0    0.28
# Name: volatile acidity, dtype: float64

# %%
df[df["volatile acidity"].isna()]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 86    white            7.2               NaN         0.63            11.0
# 521   white            7.9               NaN         0.26             2.1
# 621   white            6.5               NaN         0.43             8.9
# 812   white            6.4               NaN         0.28             1.1
# 1079  white            6.8               NaN         0.29             6.2
# 2894  white            6.4               NaN         0.36             1.4
# 4895  white            6.5               NaN         0.19             1.2
# 6486    red            7.2               NaN         0.33             2.5
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 86        0.044                 55.0                 156.0  0.99740  3.09
# 521       0.039                  8.0                 143.0  0.99420  3.05
# 621       0.083                 50.0                 171.0  0.99650  2.85
# ...

# %%
# filling of nans in volatile acidity
df["volatile acidity"]=df["volatile acidity"].fillna(df["volatile acidity"].mode()[0])

# %%
df[df["citric acid"].isna()]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 268   white            5.3             0.585          NaN             7.1
# 909   white            7.5             0.240          NaN            13.0
# 6320    red            7.0             0.540          NaN             2.1
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 268       0.044                 34.0                 145.0   0.9945  3.34
# 909       0.049                 46.0                 217.0   0.9985  3.08
# 6320      0.079                 39.0                  55.0   0.9956  3.39
#
#       sulphates  alcohol  quality
# 268        0.57      9.7        6
# 909        0.53      8.8        5
# 6320       0.84     11.4        6

# %%
# filling of nans in citric acid
df["citric acid"]=df["citric acid"].fillna(df["citric acid"].mode()[0])

# %%
df[df["residual sugar"].isna()]
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 33   white            6.2             0.120         0.34             NaN
# 438  white            7.4             0.155         0.34             NaN
#
#      chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 33       0.045                 43.0                 117.0   0.9939  3.42
# 438      0.045                 73.5                 214.0   0.9934  3.18
#
#      sulphates  alcohol  quality
# 33        0.51      9.0        6
# 438       0.61      9.9        7

# %%
# filling of nans in residual sugar
df["residual sugar"]=df["residual sugar"].fillna(df["residual sugar"].mode()[0])

# %%
# filling of nans in Chlorides
df["chlorides"]=df["chlorides"].fillna(df["chlorides"].mode()[0])

# %%
# filling of nans in pH
df["pH"]=df["pH"].fillna(df["pH"].mode()[0])

# %%
# filling of nans in sulphates
df["sulphates"]=df["sulphates"].fillna(df["sulphates"].mode()[0])

# %%
df.isna().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 6  white            6.2              0.32         0.16             7.0
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 6      0.045                 30.0                 136.0   0.9949  3.18
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
df.dtypes
# Out:
# type                     object
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.reset_index(inplace=True)

# %%
df.drop("index",axis=1,inplace=True)

# %% [markdown]
# # Data Analysis

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    5329.000000       5329.000000  5329.000000     5329.000000
# mean        7.215791          0.344027     0.318728        5.052543
# std         1.318078          0.168120     0.147076        4.503657
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.240000        1.800000
# 50%         7.000000          0.300000     0.310000        2.700000
# 75%         7.700000          0.410000     0.400000        7.500000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  5329.000000          5329.000000           5329.000000  5329.000000
# mean      0.056661            30.060143            114.189341     0.994536
# std       0.036840            17.815588             56.781422     0.002966
# ...

# %%
# for unique values in each feature
for i in df.columns:
    
    print(i,":-")
    print(df[i].nunique())
    print("************************")
# Out:
# type :-
# 2
# ************************
# fixed acidity :-
# 106
# ************************
# volatile acidity :-
# 187
# ************************
# citric acid :-
# 89
# ************************
# residual sugar :-
# 316
# ************************
# chlorides :-
# 214
# ************************
# free sulfur dioxide :-
# 135
# ************************
# total sulfur dioxide :-
# 276
# ************************
# density :-
# 998
# ************************
# pH :-
# 108
# ************************
# sulphates :-
# 111
# ************************
# alcohol :-
# 111
# ************************
# quality :-
# 7
# ************************

# %% [markdown]
# ## Non-Visual Analysis (Statistical Analysis)

# %%
#categorical and numerical features (Statistical analysis)
for i in df.columns:
    if df[i].dtype=="O":
        print("Mode:",i,df[i].mode())
        print("***********************************")
    else:
        print("Feature : ",i)
        print("Min :",df[i].min())
        print("Max :",df[i].max())
        print("Mean :",df[i].mean())
        print("Std :",df[i].std())
        print("Variance :",df[i].var())
        print("***********************************")
# Out:
# Mode: type 0    white
# Name: type, dtype: object
# ***********************************
# Feature :  fixed acidity
# Min : 3.8
# Max : 15.9
# Mean : 7.2157909551510295
# Std : 1.3180784633022318
# Variance : 1.7373308354211727
# ***********************************
# Feature :  volatile acidity
# Min : 0.08
# Max : 1.58
# Mean : 0.34402702195533774
# Std : 0.16812022686484943
# Variance : 0.028264410681088436
# ***********************************
# Feature :  citric acid
# Min : 0.0
# Max : 1.66
# Mean : 0.3187277162694646
# Std : 0.14707558035120297
# Variance : 0.02163122633564316
# ***********************************
# Feature :  residual sugar
# Min : 0.6
# Max : 65.8
# Mean : 5.052542690936391
# Std : 4.503657027666359
# Variance : 20.282926622848578
# ***********************************
# Feature :  chlorides
# Min : 0.009
# Max : 0.611
# Mean : 0.056660536686057784
# Std : 0.036839791204663366
# Variance : 0.0013571702160031925
# ***********************************
# ...

# %%
for column in df.columns:
    if df[column].dtype=="object":
        print("Feature =",column)
        print()
        print("mode:",df[column].mode())
        print("Value_counts:\n",df[column].value_counts())
        print(df[column].value_counts().plot(kind = 'bar'),plt.show())
        print("******************************************************************")
    else:
        print("Column:-",column)
        print('Mean:-',df[column].mean())
        print('Median:-',df[column].median())
        print("Std:-",df[column].std())
        print("min:-",df[column].min())
        print("max:-",df[column].max())
        print(df[column].plot(kind="box"),plt.show())
        print(df[column].plot(kind="kde"),plt.show())
        print()
        print("*************************************************************")
# Out:
# Feature = type
#
# mode: 0    white
# Name: type, dtype: object
# Value_counts:
#  white    3970
# red      1359
# Name: type, dtype: int64
# AxesSubplot(0.125,0.11;0.775x0.77) None
# ******************************************************************
# Column:- fixed acidity
# Mean:- 7.2157909551510295
# Median:- 7.0
# Std:- 1.3180784633022318
# min:- 3.8
# max:- 15.9
# AxesSubplot(0.125,0.11;0.775x0.77) None
# AxesSubplot(0.125,0.11;0.775x0.77) None
#
# *************************************************************
# Column:- volatile acidity
# Mean:- 0.34402702195533774
# Median:- 0.3
# Std:- 0.16812022686484943
# min:- 0.08
# max:- 1.58
# AxesSubplot(0.125,0.11;0.775x0.77) None
# AxesSubplot(0.125,0.11;0.775x0.77) None
#
# *************************************************************
# Column:- citric acid
# Mean:- 0.3187277162694646
# Median:- 0.31
# Std:- 0.14707558035120297
# min:- 0.0
# max:- 1.66
# AxesSubplot(0.125,0.11;0.775x0.77) None
# ...

# %%
sns.countplot(y=df["quality"])
plt.show()

# %%
df.hist(figsize=(10,10),bins=50)
plt.show()

# %% [markdown]
# ### Outlier Treatment

# %%
# Fixed Acidity
Q3 = df['fixed acidity'].quantile(0.75)
Q1 = df['fixed acidity'].quantile(0.25)
IQR = Q3 - Q1

#Define lower and upper bounds for outliers
lf = Q1 - 1.5 * IQR
uf = Q3 + 1.5 * IQR

def replace_outliers(value):
    if value < lf:
        return lf
    elif value > uf:
        return uf
    else:
        return value
    
df['fixed acidity'] = df['fixed acidity'].apply(replace_outliers)

# %%
# Volatile Acidity
Q3 = df['volatile acidity'].quantile(0.75)
Q1 = df['volatile acidity'].quantile(0.25)
IQR = Q3 - Q1

#Define lower and upper bounds for outliers
lf = Q1 - 1.5 * IQR
uf = Q3 + 1.5 * IQR

def replace_outliers(value):
    if value < lf:
        return lf
    elif value > uf:
        return uf
    else:
        return value
    
df['volatile acidity'] = df['volatile acidity'].apply(replace_outliers)

# %%
# Citric Acid
Q3 = df['citric acid'].quantile(0.75)
Q1 = df['citric acid'].quantile(0.25)
IQR = Q3 - Q1

#Define lower and upper bounds for outliers
lf = Q1 - 1.5 * IQR
uf = Q3 + 1.5 * IQR

def replace_outliers(value):
    if value < lf:
        return lf
    elif value > uf:
        return uf
    else:
        return value
    
df['citric acid'] = df['citric acid'].apply(replace_outliers)

# %%
# Residual sugar
Q3 = df['residual sugar'].quantile(0.75)
Q1 = df['residual sugar'].quantile(0.25)
IQR = Q3 - Q1

#Define lower and upper bounds for outliers
lf = Q1 - 1.5 * IQR
uf = Q3 + 1.5 * IQR

def replace_outliers(value):
    if value < lf:
        return lf
    elif value > uf:
        return uf
    else:
        return value
    
df['residual sugar'] = df['residual sugar'].apply(replace_outliers)

# %%
# chlorides
Q3 = df['chlorides'].quantile(0.75)
Q1 = df['chlorides'].quantile(0.25)
IQR = Q3 - Q1

#Define lower and upper bounds for outliers
lf = Q1 - 1.5 * IQR
uf = Q3 + 1.5 * IQR

def replace_outliers(value):
    if value < lf:
        return lf
    elif value > uf:
        return uf
    else:
        return value
    
df['chlorides'] = df['chlorides'].apply(replace_outliers)

# %%
# free sulfur dioxide
Q3 = df['free sulfur dioxide'].quantile(0.75)
Q1 = df['free sulfur dioxide'].quantile(0.25)
IQR = Q3 - Q1

#Define lower and upper bounds for outliers
lf = Q1 - 1.5 * IQR
uf = Q3 + 1.5 * IQR

def replace_outliers(value):
    if value < lf:
        return lf
    elif value > uf:
        return uf
    else:
        return value
    
df['free sulfur dioxide'] = df['free sulfur dioxide'].apply(replace_outliers)

# %%
# total sulfur dioxide
Q3 = df['total sulfur dioxide'].quantile(0.75)
Q1 = df['total sulfur dioxide'].quantile(0.25)
IQR = Q3 - Q1

#Define lower and upper bounds for outliers
lf = Q1 - 1.5 * IQR
uf = Q3 + 1.5 * IQR

def replace_outliers(value):
    if value < lf:
        return lf
    elif value > uf:
        return uf
    else:
        return value
    
df['total sulfur dioxide'] = df['total sulfur dioxide'].apply(replace_outliers)

# %%
# density
Q3 = df['density'].quantile(0.75)
Q1 = df['density'].quantile(0.25)
IQR = Q3 - Q1

#Define lower and upper bounds for outliers
lf = Q1 - 1.5 * IQR
uf = Q3 + 1.5 * IQR

def replace_outliers(value):
    if value < lf:
        return lf
    elif value > uf:
        return uf
    else:
        return value
    
df['density'] = df['density'].apply(replace_outliers)

# %%
# pH
Q3 = df['pH'].quantile(0.75)
Q1 = df['pH'].quantile(0.25)
IQR = Q3 - Q1

#Define lower and upper bounds for outliers
lf = Q1 - 1.5 * IQR
uf = Q3 + 1.5 * IQR

def replace_outliers(value):
    if value < lf:
        return lf
    elif value > uf:
        return uf
    else:
        return value
    
df['pH'] = df['pH'].apply(replace_outliers)

# %%
# sulphates
Q3 = df['sulphates'].quantile(0.75)
Q1 = df['sulphates'].quantile(0.25)
IQR = Q3 - Q1

#Define lower and upper bounds for outliers
lf = Q1 - 1.5 * IQR
uf = Q3 + 1.5 * IQR

def replace_outliers(value):
    if value < lf:
        return lf
    elif value > uf:
        return uf
    else:
        return value
    
df['sulphates'] = df['sulphates'].apply(replace_outliers)

# %%
# quality
Q3 = df['quality'].quantile(0.75)
Q1 = df['quality'].quantile(0.25)
IQR = Q3 - Q1

#Define lower and upper bounds for outliers
lf = Q1 - 1.5 * IQR
uf = Q3 + 1.5 * IQR

def replace_outliers(value):
    if value < lf:
        return lf
    elif value > uf:
        return uf
    else:
        return value
    
df['quality'] = df['quality'].apply(replace_outliers)

# %%
# alcohol
Q3 = df['alcohol'].quantile(0.75)
Q1 = df['alcohol'].quantile(0.25)
IQR = Q3 - Q1

#Define lower and upper bounds for outliers
lf = Q1 - 1.5 * IQR
uf = Q3 + 1.5 * IQR

def replace_outliers(value):
    if value < lf:
        return lf
    elif value > uf:
        return uf
    else:
        return value
    
df['alcohol'] = df['alcohol'].apply(replace_outliers)

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,6,1)
plt.boxplot(df["volatile acidity"])
plt.title("Volatile Acidity")

plt.subplot(1,6,2)
plt.boxplot(df["fixed acidity"])
plt.title("fixed acidity")

plt.subplot(1,6,3)
plt.boxplot(df["citric acid"])
plt.title("citric acid")

plt.subplot(1,6,4)
plt.boxplot(df["residual sugar"])
plt.title("residual sugar")

plt.subplot(1,6,5)
plt.boxplot(df["chlorides"])
plt.title("chlorides")

plt.subplot(1,6,6)
plt.boxplot(df["free sulfur dioxide"])
plt.title("free sulfur dioxide")


plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,6,1)
plt.boxplot(df["total sulfur dioxide"])
plt.title("total sulfur dioxide")

plt.subplot(1,6,2)
plt.boxplot(df["density"])
plt.title("density")

plt.subplot(1,6,3)
plt.boxplot(df["pH"])
plt.title("pH")

plt.subplot(1,6,4)
plt.boxplot(df["sulphates"])
plt.title("sulphates")

plt.subplot(1,6,5)
plt.boxplot(df["alcohol"])
plt.title("alcohol")

plt.subplot(1,6,6)
plt.boxplot(df["quality"])
plt.title("quality")

plt.show()

# %%
df["alcohol"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.to_csv("wine_quality_final.csv")

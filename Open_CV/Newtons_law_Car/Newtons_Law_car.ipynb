# %%
import cv2
import numpy as np

# %%
black=np.zeros((250,250,3),np.uint8)

img1=cv2.circle(black,(125,125),30,(0,0,255),2) # outline

img1=cv2.circle(black,(110,120),7,(0,0,255),2)  # eyes
img1=cv2.circle(black,(140,120),7,(0,0,255),2)

img1=cv2.line(black,(115,145),(135,145),(0,0,255),2) # mouth

img1=cv2.circle(black,(110,120),6,(255,255,255),-1) # iner eyes
img1=cv2.circle(black,(140,120),6,(255,255,255),-1)

img1=cv2.line(black,(125,155),(125,210),(0,0,255),2) # neck

img1=cv2.line(black,(180,145),(125,170),(0,0,255),2) # hands
img1=cv2.line(black,(70,150),(125,170),(0,0,255),2)


img1=cv2.line(black,(180,235),(125,210),(0,0,255),2) # legs
img1=cv2.line(black,(70,235),(125,210),(0,0,255),2)



cv2.imshow("circle",img1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# black=np.zeros((400,800,3),np.uint8)

# img1=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels
# img1=cv2.circle(black,(430,280),28,(0,0,255),3)
# img1=cv2.circle(black,(200,280),18,(0,0,255),2)
# img1=cv2.circle(black,(430,280),18,(0,0,255),2)
# img1=cv2.circle(black,(200,280),5,(250,250,255),-2)
# img1=cv2.circle(black,(430,280),5,(250,250,255),-2)

# img1=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
# img1=cv2.line(black,(180,170),(150,280),(0,0,255),3)
# img1=cv2.line(black,(150,280),(173,280),(0,0,255),3)
# img1=cv2.line(black,(230,280),(400,280),(0,0,255),3)
# img1=cv2.line(black,(170,217),(500,217),(0,0,255),3)
# img1=cv2.line(black,(500,217),(500,280),(0,0,255),3)
# img1=cv2.line(black,(500,280),(460,280),(0,0,255),3)
# img1=cv2.line(black,(370,170),(450,215),(220,220,215),3)
# img1=cv2.line(black,(370,170),(370,217),(20,240,255),2)
# img1=cv2.line(black,(280,170),(280,280),(0,0,255),3)
# img1=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
# img1=cv2.line(black,(200,170),(200,215),(0,0,255),2)

# img1=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
# img1=cv2.line(black,(1,250),(145,250),(150,150,155),15)
# img1=cv2.line(black,(510,250),(800,250),(150,150,155),15)

# # img1=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
# # img1=cv2.line(black,(500,310),(280,310),(20,250,255),5)
# # img1=cv2.line(black,(900,310),(600,310),(20,250,255),5)

# img1=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
# img1=cv2.line(black,(500,310),(680,310),(20,250,255),5)



# ##############   1


# # img1=cv2.circle(black,(650,175),20,(0,250,255),-2) # outline

# # img1=cv2.circle(black,(660,170),4,(0,2,0),-2)  # eyes
# # img1=cv2.circle(black,(640,170),4,(0,2,0),-2)

# # img1=cv2.line(black,(640,185),(660,185),(0,0,0),2) # mouth

# # img1=cv2.line(black,(650,195),(650,250),(0,255,255),2) # neck

# # img1=cv2.line(black,(680,215),(650,200),(0,250,255),2) # hands
# # img1=cv2.line(black,(620,218),(650,200),(0,250,255),2)

# # img1=cv2.line(black,(630,285),(650,250),(0,250,255),2) # legs
# # img1=cv2.line(black,(680,285),(650,250),(0,250,255),2)


# ###########################   2

# # img1=cv2.circle(black,(530,175),20,(0,250,255),-2) # outline

# # img1=cv2.circle(black,(540,170),4,(0,2,0),-2)  # eyes
# # img1=cv2.circle(black,(520,170),4,(0,2,0),-2)

# # img1=cv2.line(black,(520,185),(540,185),(0,0,0),2) # mouth

# # img1=cv2.line(black,(530,195),(530,250),(0,255,255),2) # neck

# # img1=cv2.line(black,(560,215),(530,200),(0,250,255),2) # hands
# # img1=cv2.line(black,(500,218),(530,200),(0,250,255),2)

# # img1=cv2.line(black,(560,285),(530,250),(0,250,255),2) # legs
# # img1=cv2.line(black,(500,285),(530,250),(0,250,255),2)


# ######################################### 3

# img1=cv2.circle(black,(330,115),20,(0,250,255),-2) # outline

# img1=cv2.circle(black,(320,125),4,(0,2,0),-2)  # eyes
# img1=cv2.circle(black,(320,105),4,(0,2,0),-2)
# img1=cv2.line(black,(340,105),(340,125),(0,0,0),2) # mouth
# img1=cv2.line(black,(350,115),(400,150),(0,255,255),2) # neck

# img1=cv2.line(black,(350,115),(350,150),(0,250,255),2) # hands
# img1=cv2.line(black,(350,115),(360,150),(0,250,255),2)

# img1=cv2.line(black,(400,150),(430,140),(0,250,255),2) # legs
# img1=cv2.line(black,(400,150),(410,120),(0,250,255),2)

# #####################################  4

# # img1=cv2.circle(black,(130,135),20,(0,250,255),-2) # outline

# # img1=cv2.circle(black,(125,140),4,(0,2,0),-2)  # eyes
# # img1=cv2.circle(black,(125,125),4,(0,2,0),-2)
# # img1=cv2.line(black,(140,125),(140,145),(0,0,0),2) # mouth

# # img1=cv2.line(black,(150,135),(220,105),(0,255,255),2) # neck

# # img1=cv2.line(black,(150,135),(160,90),(0,250,255),2) # hands
# # img1=cv2.line(black,(150,135),(180,90),(0,250,255),2)

# # img1=cv2.line(black,(220,105),(230,70),(0,250,255),2) # legs
# # img1=cv2.line(black,(220,105),(200,70),(0,250,255),2)

# ########################### air

# # img1=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
# # img1=cv2.line(black,(230,250),(300,250),(250,250,255),1)
# # img1=cv2.line(black,(280,130),(350,130),(250,250,255),1)
# # img1=cv2.line(black,(350,100),(430,100),(250,250,255),1)
# # img1=cv2.line(black,(500,190),(580,190),(250,250,255),1)
# # img1=cv2.line(black,(430,230),(510,230),(250,250,255),1)
# # img1=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

# img1=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
# img1=cv2.line(black,(540,280),(620,280),(250,250,255),1)
# img1=cv2.line(black,(180,130),(260,130),(250,250,255),1)
# img1=cv2.line(black,(100,190),(180,190),(250,250,255),1)
# img1=cv2.line(black,(300,250),(360,250),(250,250,255),1)
# img1=cv2.line(black,(650,230),(730,230),(250,250,255),1)
# img1=cv2.line(black,(380,200),(460,200),(250,250,255),1)





# cv2.imshow("circle",img1)
# cv2.waitKey()
# cv2.destroyAllWindows()

# %%
black=np.zeros((400,800,3),np.uint8)

img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
img0=cv2.circle(black,(430,280),28,(0,0,255),3)

# img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
# img0=cv2.circle(black,(430,280),28,(0,0,255),10)


img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)


img1=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
img1=cv2.line(black,(230,250),(300,250),(250,250,255),1)
img1=cv2.line(black,(280,130),(350,130),(250,250,255),1)
img1=cv2.line(black,(350,100),(430,100),(250,250,255),1)
img1=cv2.line(black,(500,190),(580,190),(250,250,255),1)
img1=cv2.line(black,(430,230),(510,230),(250,250,255),1)
img1=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

# img1=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
# img1=cv2.line(black,(540,280),(620,280),(250,250,255),1)
# img1=cv2.line(black,(180,130),(260,130),(250,250,255),1)
# img1=cv2.line(black,(100,190),(180,190),(250,250,255),1)
# img1=cv2.line(black,(300,250),(360,250),(250,250,255),1)
# img1=cv2.line(black,(650,230),(730,230),(250,250,255),1)
# img1=cv2.line(black,(380,200),(460,200),(250,250,255),1)

img1=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
img1=cv2.line(black,(500,310),(280,310),(20,250,255),5)
img1=cv2.line(black,(900,310),(600,310),(20,250,255),5)

# img1=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
# img1=cv2.line(black,(500,310),(680,310),(20,250,255),5)

cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img1.jpg",img0)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img3.jpg",img0)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img5.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

# img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
# img0=cv2.circle(black,(430,280),28,(0,0,255),3)

img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
img0=cv2.circle(black,(430,280),28,(0,0,255),10)


img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)


# img1=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
# img1=cv2.line(black,(230,250),(300,250),(250,250,255),1)
# img1=cv2.line(black,(280,130),(350,130),(250,250,255),1)
# img1=cv2.line(black,(350,100),(430,100),(250,250,255),1)
# img1=cv2.line(black,(500,190),(580,190),(250,250,255),1)
# img1=cv2.line(black,(430,230),(510,230),(250,250,255),1)
# img1=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

img1=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
img1=cv2.line(black,(540,280),(620,280),(250,250,255),1)
img1=cv2.line(black,(180,130),(260,130),(250,250,255),1)
img1=cv2.line(black,(100,190),(180,190),(250,250,255),1)
img1=cv2.line(black,(300,250),(360,250),(250,250,255),1)
img1=cv2.line(black,(650,230),(730,230),(250,250,255),1)
img1=cv2.line(black,(380,200),(460,200),(250,250,255),1)

# img1=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
# img1=cv2.line(black,(500,310),(280,310),(20,250,255),5)
# img1=cv2.line(black,(900,310),(600,310),(20,250,255),5)

img1=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
img1=cv2.line(black,(500,310),(680,310),(20,250,255),5)

cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img2.jpg",img0)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img4.jpg",img0)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img6.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

img1=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels
img1=cv2.circle(black,(430,280),28,(0,0,255),3)
img1=cv2.circle(black,(200,280),18,(0,0,255),2)
img1=cv2.circle(black,(430,280),18,(0,0,255),2)
img1=cv2.circle(black,(200,280),5,(250,250,255),-2)
img1=cv2.circle(black,(430,280),5,(250,250,255),-2)

img1=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img1=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img1=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img1=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img1=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img1=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img1=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img1=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img1=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img1=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img1=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img1=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img1=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img1=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img1=cv2.line(black,(510,250),(800,250),(150,150,155),15)

img1=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
img1=cv2.line(black,(500,310),(280,310),(20,250,255),5)
img1=cv2.line(black,(900,310),(600,310),(20,250,255),5)

img1=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
img1=cv2.line(black,(230,250),(300,250),(250,250,255),1)
img1=cv2.line(black,(280,130),(350,130),(250,250,255),1)
img1=cv2.line(black,(350,100),(430,100),(250,250,255),1)
img1=cv2.line(black,(500,190),(580,190),(250,250,255),1)
img1=cv2.line(black,(430,230),(510,230),(250,250,255),1)
img1=cv2.line(black,(100,230),(180,230),(250,250,255),1)

img1=cv2.circle(black,(650,175),20,(0,250,255),-2) # outline

img1=cv2.circle(black,(660,170),4,(0,2,0),-2)  # eyes
img1=cv2.circle(black,(640,170),4,(0,2,0),-2)

img1=cv2.line(black,(640,185),(660,185),(0,0,0),2) # mouth

img1=cv2.line(black,(650,195),(650,250),(0,255,255),2) # neck

img1=cv2.line(black,(680,215),(650,200),(0,250,255),2) # hands
img1=cv2.line(black,(620,218),(650,200),(0,250,255),2)

img1=cv2.line(black,(630,285),(650,250),(0,250,255),2) # legs
img1=cv2.line(black,(680,285),(650,250),(0,250,255),2)



cv2.imshow("circle",img1)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img7.jpg",img1)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

img2=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels
img2=cv2.circle(black,(430,280),28,(0,0,255),10)
img2=cv2.circle(black,(200,280),18,(0,0,255),2)
img2=cv2.circle(black,(430,280),18,(0,0,255),2)
img2=cv2.circle(black,(200,280),5,(250,250,255),-2)
img2=cv2.circle(black,(430,280),5,(250,250,255),-2)

img2=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img2=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img2=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img2=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img2=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img2=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img2=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img2=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img2=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img2=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img2=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img2=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img2=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img2=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img2=cv2.line(black,(510,250),(800,250),(150,150,155),15)

img2=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
img2=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img2=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
img2=cv2.line(black,(540,280),(620,280),(250,250,255),1)
img2=cv2.line(black,(180,130),(260,130),(250,250,255),1)
img2=cv2.line(black,(100,190),(180,190),(250,250,255),1)
img2=cv2.line(black,(300,250),(360,250),(250,250,255),1)
img2=cv2.line(black,(650,230),(730,230),(250,250,255),1)
img2=cv2.line(black,(380,200),(460,200),(250,250,255),1)


img2=cv2.circle(black,(530,175),20,(0,250,255),-2) # outline
img2=cv2.circle(black,(540,170),4,(0,2,0),-2)  # eyes
img2=cv2.circle(black,(520,170),4,(0,2,0),-2)
img2=cv2.line(black,(520,185),(540,185),(0,0,0),2) # mouth
img2=cv2.line(black,(530,195),(530,250),(0,255,255),2) # neck
img2=cv2.line(black,(560,215),(530,200),(0,250,255),2) # hands
img2=cv2.line(black,(500,218),(530,200),(0,250,255),2)
img2=cv2.line(black,(560,285),(530,250),(0,250,255),2) # legs
img2=cv2.line(black,(500,285),(530,250),(0,250,255),2)


cv2.imshow("circle",img2)
cv2.waitKey()
cv2.destroyAllWindows()
cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img8.jpg",img2)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

img3=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels
img3=cv2.circle(black,(430,280),28,(0,0,255),3)
img3=cv2.circle(black,(200,280),18,(0,0,255),2)
img3=cv2.circle(black,(430,280),18,(0,0,255),2)
img3=cv2.circle(black,(200,280),5,(250,250,255),-2)
img3=cv2.circle(black,(430,280),5,(250,250,255),-2)

img3=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img3=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img3=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img3=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img3=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img3=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img3=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img3=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img3=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img3=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img3=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img3=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img3=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img3=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img3=cv2.line(black,(510,250),(800,250),(150,150,155),15)

img3=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
img3=cv2.line(black,(500,310),(280,310),(20,250,255),5)
img3=cv2.line(black,(900,310),(600,310),(20,250,255),5)

img3=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
img3=cv2.line(black,(230,250),(300,250),(250,250,255),1)
img3=cv2.line(black,(280,130),(350,130),(250,250,255),1)
img3=cv2.line(black,(350,100),(430,100),(250,250,255),1)
img3=cv2.line(black,(500,190),(580,190),(250,250,255),1)
img3=cv2.line(black,(430,230),(510,230),(250,250,255),1)
img3=cv2.line(black,(100,230),(180,230),(250,250,255),1)

img3=cv2.circle(black,(330,115),20,(0,250,255),-2) # outline

img3=cv2.circle(black,(320,125),4,(0,2,0),-2)  # eyes
img3=cv2.circle(black,(320,105),4,(0,2,0),-2)
img3=cv2.line(black,(340,105),(340,125),(0,0,0),2) # mouth
img3=cv2.line(black,(350,115),(400,150),(0,255,255),2) # neck
img3=cv2.line(black,(350,115),(350,150),(0,250,255),2) # hands
img3=cv2.line(black,(350,115),(360,150),(0,250,255),2)
img3=cv2.line(black,(400,150),(430,140),(0,250,255),2) # legs
img3=cv2.line(black,(400,150),(410,120),(0,250,255),2)


cv2.imshow("circle",img3)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img9.jpg",img3)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

img4=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels
img4=cv2.circle(black,(430,280),28,(0,0,255),10)
img4=cv2.circle(black,(200,280),18,(0,0,255),2)
img4=cv2.circle(black,(430,280),18,(0,0,255),2)
img4=cv2.circle(black,(200,280),5,(250,250,255),-2)
img4=cv2.circle(black,(430,280),5,(250,250,255),-2)

img4=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img4=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img4=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img4=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img4=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img4=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img4=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img4=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img4=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img4=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img4=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img4=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img4=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img4=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img4=cv2.line(black,(510,250),(800,250),(150,150,155),15)

img4=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
img4=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img4=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
img4=cv2.line(black,(540,280),(620,280),(250,250,255),1)
img4=cv2.line(black,(180,130),(260,130),(250,250,255),1)
img4=cv2.line(black,(100,190),(180,190),(250,250,255),1)
img4=cv2.line(black,(300,250),(360,250),(250,250,255),1)
img4=cv2.line(black,(650,230),(730,230),(250,250,255),1)
img4=cv2.line(black,(380,200),(460,200),(250,250,255),1)

img4=cv2.circle(black,(130,135),20,(0,250,255),-2) # outline
img4=cv2.circle(black,(125,140),4,(0,2,0),-2)  # eyes
img4=cv2.circle(black,(125,125),4,(0,2,0),-2)
img4=cv2.line(black,(140,125),(140,145),(0,0,0),2) # mouth
img4=cv2.line(black,(150,135),(220,105),(0,255,255),2) # neck
img4=cv2.line(black,(150,135),(160,90),(0,250,255),2) # hands
img4=cv2.line(black,(150,135),(180,90),(0,250,255),2)
img4=cv2.line(black,(220,105),(230,70),(0,250,255),2) # legs
img4=cv2.line(black,(220,105),(200,70),(0,250,255),2)

cv2.imshow("circle",img4)
cv2.waitKey()
cv2.destroyAllWindows()
cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img10.jpg",img4)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
img0=cv2.circle(black,(430,280),28,(0,0,255),3)

# img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
# img0=cv2.circle(black,(430,280),28,(0,0,255),10)

img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)

img0=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
img0=cv2.line(black,(230,250),(300,250),(250,250,255),1)
img0=cv2.line(black,(280,130),(350,130),(250,250,255),1)
img0=cv2.line(black,(350,100),(430,100),(250,250,255),1)
img0=cv2.line(black,(500,190),(580,190),(250,250,255),1)
img0=cv2.line(black,(430,230),(510,230),(250,250,255),1)
img0=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

# img0=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
# img0=cv2.line(black,(540,280),(620,280),(250,250,255),1)
# img0=cv2.line(black,(180,130),(260,130),(250,250,255),1)
# img0=cv2.line(black,(100,190),(180,190),(250,250,255),1)
# img0=cv2.line(black,(300,250),(360,250),(250,250,255),1)
# img0=cv2.line(black,(650,230),(730,230),(250,250,255),1)
# img0=cv2.line(black,(380,200),(460,200),(250,250,255),1)

img0=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
img0=cv2.line(black,(500,310),(280,310),(20,250,255),5)
img0=cv2.line(black,(900,310),(600,310),(20,250,255),5)

# img0=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
# img0=cv2.line(black,(500,310),(680,310),(20,250,255),5)


img0=cv2.line(black,(750,50),(750,280),(255,255,255),3) # Truck
img0=cv2.line(black,(750,50),(800,50),(255,255,255),3)
img0=cv2.line(black,(750,280),(800,280),(255,255,255),3)

black=cv2.rectangle(black,(750,50),(850,280),(0,71,124),-10) 

cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img11.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

# img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
# img0=cv2.circle(black,(430,280),28,(0,0,255),3)

img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
img0=cv2.circle(black,(430,280),28,(0,0,255),10)

img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)

# img0=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
# img0=cv2.line(black,(230,250),(300,250),(250,250,255),1)
# img0=cv2.line(black,(280,130),(350,130),(250,250,255),1)
# img0=cv2.line(black,(350,100),(430,100),(250,250,255),1)
# img0=cv2.line(black,(500,190),(580,190),(250,250,255),1)
# img0=cv2.line(black,(430,230),(510,230),(250,250,255),1)
# img0=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

img0=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
img0=cv2.line(black,(540,280),(620,280),(250,250,255),1)
img0=cv2.line(black,(180,130),(260,130),(250,250,255),1)
img0=cv2.line(black,(100,190),(180,190),(250,250,255),1)
img0=cv2.line(black,(300,250),(360,250),(250,250,255),1)
img0=cv2.line(black,(650,230),(730,230),(250,250,255),1)
img0=cv2.line(black,(380,200),(460,200),(250,250,255),1)

# img0=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
# img0=cv2.line(black,(500,310),(280,310),(20,250,255),5)
# img0=cv2.line(black,(900,310),(600,310),(20,250,255),5)

img0=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
img0=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img0=cv2.rectangle(black,(700,50),(850,280),(0,71,124),-10) # Truck


cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img12.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
img0=cv2.circle(black,(430,280),28,(0,0,255),3)

# img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
# img0=cv2.circle(black,(430,280),28,(0,0,255),10)

img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)

img0=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
img0=cv2.line(black,(230,250),(300,250),(250,250,255),1)
img0=cv2.line(black,(280,130),(350,130),(250,250,255),1)
img0=cv2.line(black,(350,100),(430,100),(250,250,255),1)
img0=cv2.line(black,(500,190),(580,190),(250,250,255),1)
img0=cv2.line(black,(430,230),(510,230),(250,250,255),1)
img0=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

# img0=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
# img0=cv2.line(black,(540,280),(620,280),(250,250,255),1)
# img0=cv2.line(black,(180,130),(260,130),(250,250,255),1)
# img0=cv2.line(black,(100,190),(180,190),(250,250,255),1)
# img0=cv2.line(black,(300,250),(360,250),(250,250,255),1)
# img0=cv2.line(black,(650,230),(730,230),(250,250,255),1)
# img0=cv2.line(black,(380,200),(460,200),(250,250,255),1)

img0=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
img0=cv2.line(black,(500,310),(280,310),(20,250,255),5)
img0=cv2.line(black,(900,310),(600,310),(20,250,255),5)

# img0=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
# img0=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img0=cv2.rectangle(black,(670,50),(850,280),(0,71,124),-10) # Truck


cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img13.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

# img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
# img0=cv2.circle(black,(430,280),28,(0,0,255),3)

img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
img0=cv2.circle(black,(430,280),28,(0,0,255),10)

img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)

# img0=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
# img0=cv2.line(black,(230,250),(300,250),(250,250,255),1)
# img0=cv2.line(black,(280,130),(350,130),(250,250,255),1)
# img0=cv2.line(black,(350,100),(430,100),(250,250,255),1)
# img0=cv2.line(black,(500,190),(580,190),(250,250,255),1)
# img0=cv2.line(black,(430,230),(510,230),(250,250,255),1)
# img0=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

img0=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
img0=cv2.line(black,(540,280),(620,280),(250,250,255),1)
img0=cv2.line(black,(180,130),(260,130),(250,250,255),1)
img0=cv2.line(black,(100,190),(180,190),(250,250,255),1)
img0=cv2.line(black,(300,250),(360,250),(250,250,255),1)
img0=cv2.line(black,(650,230),(730,230),(250,250,255),1)
img0=cv2.line(black,(380,200),(460,200),(250,250,255),1)

# img0=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
# img0=cv2.line(black,(500,310),(280,310),(20,250,255),5)
# img0=cv2.line(black,(900,310),(600,310),(20,250,255),5)

img0=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
img0=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img0=cv2.rectangle(black,(640,50),(850,280),(0,71,124),-10) # Truck


cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img14.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
img0=cv2.circle(black,(430,280),28,(0,0,255),3)

# img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
# img0=cv2.circle(black,(430,280),28,(0,0,255),10)

img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)

img0=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
img0=cv2.line(black,(230,250),(300,250),(250,250,255),1)
img0=cv2.line(black,(280,130),(350,130),(250,250,255),1)
img0=cv2.line(black,(350,100),(430,100),(250,250,255),1)
img0=cv2.line(black,(500,190),(580,190),(250,250,255),1)
img0=cv2.line(black,(430,230),(510,230),(250,250,255),1)
img0=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

# img0=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
# img0=cv2.line(black,(540,280),(620,280),(250,250,255),1)
# img0=cv2.line(black,(180,130),(260,130),(250,250,255),1)
# img0=cv2.line(black,(100,190),(180,190),(250,250,255),1)
# img0=cv2.line(black,(300,250),(360,250),(250,250,255),1)
# img0=cv2.line(black,(650,230),(730,230),(250,250,255),1)
# img0=cv2.line(black,(380,200),(460,200),(250,250,255),1)

img0=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
img0=cv2.line(black,(500,310),(280,310),(20,250,255),5)
img0=cv2.line(black,(900,310),(600,310),(20,250,255),5)

# img0=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
# img0=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img0=cv2.rectangle(black,(640,50),(850,280),(0,71,124),-10) # Truck

img0=cv2.circle(black,(800,280),35,(128, 128, 128),-10) # wheels
img0=cv2.circle(black,(800,280),15,(211, 211, 211),-10)
img0=cv2.circle(black,(800,280),15,(0,0,0),5)


cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img15.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

# img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
# img0=cv2.circle(black,(430,280),28,(0,0,255),3)

img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
img0=cv2.circle(black,(430,280),28,(0,0,255),10)

img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)

# img0=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
# img0=cv2.line(black,(230,250),(300,250),(250,250,255),1)
# img0=cv2.line(black,(280,130),(350,130),(250,250,255),1)
# img0=cv2.line(black,(350,100),(430,100),(250,250,255),1)
# img0=cv2.line(black,(500,190),(580,190),(250,250,255),1)
# img0=cv2.line(black,(430,230),(510,230),(250,250,255),1)
# img0=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

img0=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
img0=cv2.line(black,(540,280),(620,280),(250,250,255),1)
img0=cv2.line(black,(180,130),(260,130),(250,250,255),1)
img0=cv2.line(black,(100,190),(180,190),(250,250,255),1)
img0=cv2.line(black,(300,250),(360,250),(250,250,255),1)
img0=cv2.line(black,(650,230),(730,230),(250,250,255),1)
img0=cv2.line(black,(380,200),(460,200),(250,250,255),1)

# img0=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
# img0=cv2.line(black,(500,310),(280,310),(20,250,255),5)
# img0=cv2.line(black,(900,310),(600,310),(20,250,255),5)

img0=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
img0=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img0=cv2.rectangle(black,(600,50),(850,280),(0,71,124),-10) # Truck

img0=cv2.circle(black,(750,280),35,(128, 128, 128),-10) # wheels
img0=cv2.circle(black,(750,280),15,(211, 211, 211),-10)
img0=cv2.circle(black,(750,280),15,(0,0,0),5)


cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img16.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
img0=cv2.circle(black,(430,280),28,(0,0,255),3)

# img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
# img0=cv2.circle(black,(430,280),28,(0,0,255),10)

img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)

img0=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
img0=cv2.line(black,(230,250),(300,250),(250,250,255),1)
img0=cv2.line(black,(280,130),(350,130),(250,250,255),1)
img0=cv2.line(black,(350,100),(430,100),(250,250,255),1)
img0=cv2.line(black,(500,190),(580,190),(250,250,255),1)
img0=cv2.line(black,(430,230),(510,230),(250,250,255),1)
img0=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

# img0=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
# img0=cv2.line(black,(540,280),(620,280),(250,250,255),1)
# img0=cv2.line(black,(180,130),(260,130),(250,250,255),1)
# img0=cv2.line(black,(100,190),(180,190),(250,250,255),1)
# img0=cv2.line(black,(300,250),(360,250),(250,250,255),1)
# img0=cv2.line(black,(650,230),(730,230),(250,250,255),1)
# img0=cv2.line(black,(380,200),(460,200),(250,250,255),1)

img0=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
img0=cv2.line(black,(500,310),(280,310),(20,250,255),5)
img0=cv2.line(black,(900,310),(600,310),(20,250,255),5)

# img0=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
# img0=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img0=cv2.rectangle(black,(560,50),(850,280),(0,71,124),-10) # Truck

img0=cv2.circle(black,(720,280),35,(128, 128, 128),-10) # wheels
img0=cv2.circle(black,(720,280),15,(211, 211, 211),-10)
img0=cv2.circle(black,(720,280),15,(0,0,0),5)


cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img17.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

# img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
# img0=cv2.circle(black,(430,280),28,(0,0,255),3)

img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
img0=cv2.circle(black,(430,280),28,(0,0,255),10)

img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)

# img0=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
# img0=cv2.line(black,(500,310),(280,310),(20,250,255),5)
# img0=cv2.line(black,(900,310),(600,310),(20,250,255),5)

img0=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
img0=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img0=cv2.rectangle(black,(540,50),(850,280),(0,71,124),-10) # Truck

img0=cv2.circle(black,(680,280),35,(128, 128, 128),-10) # wheels
img0=cv2.circle(black,(680,280),15,(211, 211, 211),-10)
img0=cv2.circle(black,(680,280),15,(0,0,0),5)

# img0=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
# img0=cv2.line(black,(230,250),(300,250),(250,250,255),1)
# img0=cv2.line(black,(280,130),(350,130),(250,250,255),1)
# img0=cv2.line(black,(350,100),(430,100),(250,250,255),1)
# img0=cv2.line(black,(500,190),(580,190),(250,250,255),1)
# img0=cv2.line(black,(430,230),(510,230),(250,250,255),1)
# img0=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

img0=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
img0=cv2.line(black,(540,280),(620,280),(250,250,255),1)
img0=cv2.line(black,(180,130),(260,130),(250,250,255),1)
img0=cv2.line(black,(100,190),(180,190),(250,250,255),1)
img0=cv2.line(black,(300,250),(360,250),(250,250,255),1)
img0=cv2.line(black,(650,230),(730,230),(250,250,255),1)
img0=cv2.line(black,(380,200),(460,200),(250,250,255),1)

cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img18.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
img0=cv2.circle(black,(430,280),28,(0,0,255),3)

# img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
# img0=cv2.circle(black,(430,280),28,(0,0,255),10)

img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)

img0=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
img0=cv2.line(black,(500,310),(280,310),(20,250,255),5)
img0=cv2.line(black,(900,310),(600,310),(20,250,255),5)

# img0=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
# img0=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img0=cv2.rectangle(black,(530,50),(850,280),(0,71,124),-10) # Truck

img0=cv2.circle(black,(650,280),35,(128, 128, 128),-10) # wheels
img0=cv2.circle(black,(650,280),15,(211, 211, 211),-10)
img0=cv2.circle(black,(650,280),15,(0,0,0),5)

img0=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
img0=cv2.line(black,(230,250),(300,250),(250,250,255),1)
img0=cv2.line(black,(280,130),(350,130),(250,250,255),1)
img0=cv2.line(black,(350,100),(430,100),(250,250,255),1)
img0=cv2.line(black,(500,190),(580,190),(250,250,255),1)
img0=cv2.line(black,(430,230),(510,230),(250,250,255),1)
img0=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

# img0=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
# img0=cv2.line(black,(540,280),(620,280),(250,250,255),1)
# img0=cv2.line(black,(180,130),(260,130),(250,250,255),1)
# img0=cv2.line(black,(100,190),(180,190),(250,250,255),1)
# img0=cv2.line(black,(300,250),(360,250),(250,250,255),1)
# img0=cv2.line(black,(650,230),(730,230),(250,250,255),1)
# img0=cv2.line(black,(380,200),(460,200),(250,250,255),1)

cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img19.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

# img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
# img0=cv2.circle(black,(430,280),28,(0,0,255),3)

img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
img0=cv2.circle(black,(430,280),28,(0,0,255),10)

img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)

# img0=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
# img0=cv2.line(black,(500,310),(280,310),(20,250,255),5)
# img0=cv2.line(black,(900,310),(600,310),(20,250,255),5)

img0=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
img0=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img0=cv2.rectangle(black,(500,50),(850,280),(0,71,124),-10) # Truck

img0=cv2.circle(black,(650,280),35,(128, 128, 128),-10) # wheels
img0=cv2.circle(black,(650,280),15,(211, 211, 211),-10)
img0=cv2.circle(black,(650,280),15,(0,0,0),5)

# img0=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
# img0=cv2.line(black,(230,250),(300,250),(250,250,255),1)
# img0=cv2.line(black,(280,130),(350,130),(250,250,255),1)
# img0=cv2.line(black,(350,100),(430,100),(250,250,255),1)
# img0=cv2.line(black,(500,190),(580,190),(250,250,255),1)
# img0=cv2.line(black,(430,230),(510,230),(250,250,255),1)
# img0=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

img0=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
img0=cv2.line(black,(540,280),(620,280),(250,250,255),1)
img0=cv2.line(black,(180,130),(260,130),(250,250,255),1)
img0=cv2.line(black,(100,190),(180,190),(250,250,255),1)
img0=cv2.line(black,(300,250),(360,250),(250,250,255),1)
img0=cv2.line(black,(650,230),(730,230),(250,250,255),1)
img0=cv2.line(black,(380,200),(460,200),(250,250,255),1)

cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img20.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

# img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
# img0=cv2.circle(black,(430,280),28,(0,0,255),3)

img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
img0=cv2.circle(black,(430,280),28,(0,0,255),10)

img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)

# img0=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
# img0=cv2.line(black,(500,310),(280,310),(20,250,255),5)
# img0=cv2.line(black,(900,310),(600,310),(20,250,255),5)

img0=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
img0=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img0=cv2.rectangle(black,(500,50),(850,280),(0,71,124),-10) # Truck

img0=cv2.circle(black,(650,280),35,(128, 128, 128),-10) # wheels
img0=cv2.circle(black,(650,280),15,(211, 211, 211),-10)
img0=cv2.circle(black,(650,280),15,(0,0,0),5)

# img0=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
# img0=cv2.line(black,(230,250),(300,250),(250,250,255),1)
# img0=cv2.line(black,(280,130),(350,130),(250,250,255),1)
# img0=cv2.line(black,(350,100),(430,100),(250,250,255),1)
# img0=cv2.line(black,(500,190),(580,190),(250,250,255),1)
# img0=cv2.line(black,(430,230),(510,230),(250,250,255),1)
# img0=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

img0=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
img0=cv2.line(black,(540,280),(620,280),(250,250,255),1)
img0=cv2.line(black,(180,130),(260,130),(250,250,255),1)
img0=cv2.line(black,(100,190),(180,190),(250,250,255),1)
img0=cv2.line(black,(300,250),(360,250),(250,250,255),1)
img0=cv2.line(black,(650,230),(730,230),(250,250,255),1)
img0=cv2.line(black,(380,200),(460,200),(250,250,255),1)

img0=cv2.circle(black,(500,250),40,(255,255,255),-10) #boom
img0=cv2.circle(black,(500,200),20,(255,255,255),-10) 
img0=cv2.circle(black,(500,300),30,(255,255,255),-10) 
img0=cv2.circle(black,(450,220),40,(255,255,255),-10)
img0=cv2.circle(black,(550,250),40,(255,255,255),-10)
img0=cv2.circle(black,(450,280),50,(255,255,255),-15)

img0=cv2.putText(black,"BOOM !",(440,215),cv2.FONT_HERSHEY_COMPLEX,0.5,(0,0,255),2) # text
img0=cv2.putText(black,"BOOM !",(440,245),cv2.FONT_HERSHEY_COMPLEX,0.8,(0,240,255),2)
img0=cv2.putText(black,"BOOM !",(440,280),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)


cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img21.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

# img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
# img0=cv2.circle(black,(430,280),28,(0,0,255),3)

img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
img0=cv2.circle(black,(430,280),28,(0,0,255),10)

img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)

# img0=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
# img0=cv2.line(black,(500,310),(280,310),(20,250,255),5)
# img0=cv2.line(black,(900,310),(600,310),(20,250,255),5)

img0=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
img0=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img0=cv2.rectangle(black,(500,50),(850,280),(0,71,124),-10) # Truck

img0=cv2.circle(black,(650,280),35,(128, 128, 128),-10) # wheels
img0=cv2.circle(black,(650,280),15,(211, 211, 211),-10)
img0=cv2.circle(black,(650,280),15,(0,0,0),5)

# img0=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
# img0=cv2.line(black,(230,250),(300,250),(250,250,255),1)
# img0=cv2.line(black,(280,130),(350,130),(250,250,255),1)
# img0=cv2.line(black,(350,100),(430,100),(250,250,255),1)
# img0=cv2.line(black,(500,190),(580,190),(250,250,255),1)
# img0=cv2.line(black,(430,230),(510,230),(250,250,255),1)
# img0=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

img0=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
img0=cv2.line(black,(540,280),(620,280),(250,250,255),1)
img0=cv2.line(black,(180,130),(260,130),(250,250,255),1)
img0=cv2.line(black,(100,190),(180,190),(250,250,255),1)
img0=cv2.line(black,(300,250),(360,250),(250,250,255),1)
img0=cv2.line(black,(650,230),(730,230),(250,250,255),1)
img0=cv2.line(black,(380,200),(460,200),(250,250,255),1)

img0=cv2.circle(black,(500,250),40,(255,255,255),-10) #boom
img0=cv2.circle(black,(500,200),20,(255,255,255),-10) 
img0=cv2.circle(black,(500,300),100,(255,255,255),-10) 
img0=cv2.circle(black,(450,220),40,(255,255,255),-10)
img0=cv2.circle(black,(550,250),140,(255,255,255),-10)
img0=cv2.circle(black,(450,280),50,(255,255,255),-15)
img0=cv2.circle(black,(450,200),100,(255,255,255),-15)
img0=cv2.circle(black,(350,220),80,(255,255,255),-10)
img0=cv2.circle(black,(450,220),40,(255,255,255),-10)


img0=cv2.putText(black,"BOOM !",(440,215),cv2.FONT_HERSHEY_COMPLEX,0.5,(0,0,255),2) # text
img0=cv2.putText(black,"BOOM !",(440,245),cv2.FONT_HERSHEY_COMPLEX,0.8,(0,240,255),2)
img0=cv2.putText(black,"BOOM !",(440,280),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,255),4)


cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img22.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

# img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
# img0=cv2.circle(black,(430,280),28,(0,0,255),3)

img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
img0=cv2.circle(black,(430,280),28,(0,0,255),10)

img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)

# img0=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
# img0=cv2.line(black,(500,310),(280,310),(20,250,255),5)
# img0=cv2.line(black,(900,310),(600,310),(20,250,255),5)

img0=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
img0=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img0=cv2.rectangle(black,(500,50),(850,280),(0,71,124),-10) # Truck

img0=cv2.circle(black,(650,280),35,(128, 128, 128),-10) # wheels
img0=cv2.circle(black,(650,280),15,(211, 211, 211),-10)
img0=cv2.circle(black,(650,280),15,(0,0,0),5)

# img0=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
# img0=cv2.line(black,(230,250),(300,250),(250,250,255),1)
# img0=cv2.line(black,(280,130),(350,130),(250,250,255),1)
# img0=cv2.line(black,(350,100),(430,100),(250,250,255),1)
# img0=cv2.line(black,(500,190),(580,190),(250,250,255),1)
# img0=cv2.line(black,(430,230),(510,230),(250,250,255),1)
# img0=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

img0=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
img0=cv2.line(black,(540,280),(620,280),(250,250,255),1)
img0=cv2.line(black,(180,130),(260,130),(250,250,255),1)
img0=cv2.line(black,(100,190),(180,190),(250,250,255),1)
img0=cv2.line(black,(300,250),(360,250),(250,250,255),1)
img0=cv2.line(black,(650,230),(730,230),(250,250,255),1)
img0=cv2.line(black,(380,200),(460,200),(250,250,255),1)

img0=cv2.circle(black,(500,250),40,(255,255,255),-10) #boom
img0=cv2.circle(black,(500,200),20,(255,255,255),-10) 
img0=cv2.circle(black,(500,300),100,(255,255,255),-10) 
img0=cv2.circle(black,(450,220),40,(255,255,255),-10)
img0=cv2.circle(black,(550,250),140,(255,255,255),-10)
img0=cv2.circle(black,(450,280),50,(255,255,255),-15)
img0=cv2.circle(black,(450,200),100,(255,255,255),-15)
img0=cv2.circle(black,(350,220),80,(255,255,255),-10)
img0=cv2.circle(black,(450,220),40,(255,255,255),-10)
img0=cv2.circle(black,(380,220),180,(255,255,255),-10)
img0=cv2.circle(black,(150,220),150,(255,255,255),-10)
img0=cv2.circle(black,(590,220),180,(255,255,255),-10)


img0=cv2.putText(black,"BOOM !",(440,200),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,255),2) # text
img0=cv2.putText(black,"BOOM !",(440,235),cv2.FONT_HERSHEY_COMPLEX,1,(0,240,255),2)
img0=cv2.putText(black,"BOOM !",(440,280),cv2.FONT_HERSHEY_COMPLEX,1.5,(0,0,255),4)


cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img23.jpg",img0)
# Out:
# True

# %%
black=np.zeros((400,800,3),np.uint8)

# img0=cv2.circle(black,(200,280),28,(0,0,255),3) # wheels 1
# img0=cv2.circle(black,(430,280),28,(0,0,255),3)

img0=cv2.circle(black,(200,280),28,(0,0,255),10) # wheels 2
img0=cv2.circle(black,(430,280),28,(0,0,255),10)

img0=cv2.circle(black,(200,280),18,(0,0,255),2)
img0=cv2.circle(black,(430,280),18,(0,0,255),2)
img0=cv2.circle(black,(200,280),5,(250,250,255),-2)
img0=cv2.circle(black,(430,280),5,(250,250,255),-2)

img0=cv2.line(black,(178,170),(370,170),(0,0,255),3) # Outline
img0=cv2.line(black,(180,170),(150,280),(0,0,255),3)
img0=cv2.line(black,(150,280),(173,280),(0,0,255),3)
img0=cv2.line(black,(230,280),(400,280),(0,0,255),3)
img0=cv2.line(black,(170,217),(500,217),(0,0,255),3)
img0=cv2.line(black,(500,217),(500,280),(0,0,255),3)
img0=cv2.line(black,(500,280),(460,280),(0,0,255),3)
img0=cv2.line(black,(370,170),(450,215),(220,220,215),3)
img0=cv2.line(black,(370,170),(370,217),(20,240,255),2)
img0=cv2.line(black,(280,170),(280,280),(0,0,255),3)
img0=cv2.rectangle(black,(180,220),(200,235),(25,250,255),2)
img0=cv2.line(black,(200,170),(200,215),(0,0,255),2)

img0=cv2.line(black,(1,380),(800,380),(150,150,155),15) # Road
img0=cv2.line(black,(1,250),(145,250),(150,150,155),15)
img0=cv2.line(black,(510,250),(800,250),(150,150,155),15)

# img0=cv2.line(black,(1,310),(140,310),(20,250,255),5) # lines 1
# img0=cv2.line(black,(500,310),(280,310),(20,250,255),5)
# img0=cv2.line(black,(900,310),(600,310),(20,250,255),5)

img0=cv2.line(black,(150,310),(350,310),(20,250,255),5) # lines 2
img0=cv2.line(black,(500,310),(680,310),(20,250,255),5)

img0=cv2.rectangle(black,(500,50),(850,280),(0,71,124),-10) # Truck

img0=cv2.circle(black,(650,280),35,(128, 128, 128),-10) # wheels
img0=cv2.circle(black,(650,280),15,(211, 211, 211),-10)
img0=cv2.circle(black,(650,280),15,(0,0,0),5)

# img0=cv2.line(black,(200,150),(150,150),(250,250,255),1) # air 1
# img0=cv2.line(black,(230,250),(300,250),(250,250,255),1)
# img0=cv2.line(black,(280,130),(350,130),(250,250,255),1)
# img0=cv2.line(black,(350,100),(430,100),(250,250,255),1)
# img0=cv2.line(black,(500,190),(580,190),(250,250,255),1)
# img0=cv2.line(black,(430,230),(510,230),(250,250,255),1)
# img0=cv2.line(black,(100,230),(180,230),(250,250,255),1)

# ########################################################

img0=cv2.line(black,(600,150),(680,150),(250,250,255),1) # air 2
img0=cv2.line(black,(540,280),(620,280),(250,250,255),1)
img0=cv2.line(black,(180,130),(260,130),(250,250,255),1)
img0=cv2.line(black,(100,190),(180,190),(250,250,255),1)
img0=cv2.line(black,(300,250),(360,250),(250,250,255),1)
img0=cv2.line(black,(650,230),(730,230),(250,250,255),1)
img0=cv2.line(black,(380,200),(460,200),(250,250,255),1)

img0=cv2.circle(black,(500,250),40,(255,255,255),-10) #boom
img0=cv2.circle(black,(500,200),20,(255,255,255),-10) 
img0=cv2.circle(black,(500,300),100,(255,255,255),-10) 
img0=cv2.circle(black,(450,220),40,(255,255,255),-10)
img0=cv2.circle(black,(550,250),140,(255,255,255),-10)
img0=cv2.circle(black,(450,280),50,(255,255,255),-15)
img0=cv2.circle(black,(450,200),100,(255,255,255),-15)
img0=cv2.circle(black,(350,220),80,(255,255,255),-10)
img0=cv2.circle(black,(450,220),40,(255,255,255),-10)
img0=cv2.circle(black,(380,220),180,(255,255,255),-10)
img0=cv2.circle(black,(150,220),150,(255,255,255),-10)
img0=cv2.circle(black,(590,220),180,(255,255,255),-10)
img0=cv2.circle(black,(500,220),580,(255,255,255),-10)

img0=cv2.putText(black,"For every action in nature",(20,100),cv2.FONT_HERSHEY_COMPLEX,1.6,(0,0,255),3) # text
img0=cv2.putText(black,"there is an equal",(150,200),cv2.FONT_HERSHEY_COMPLEX,1.6,(0,0,255),3)
img0=cv2.putText(black,"and opposite reaction!",(90,300),cv2.FONT_HERSHEY_COMPLEX,1.6,(0,0,255),3)


cv2.imshow("circle",img0)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img24.jpg",img0)
# Out:
# True

# %%
cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\task2\i0.jpg",img0)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\task2\i1.jpg",img1)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\task2\i2.jpg",img2)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\task2\i3.jpg",img3)
cv2.imwrite(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\task2\i4.jpg",img4)
# Out:
# True

# %%
count=1
while True :
    imgf=cv2.imread(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\Task_2\images\img{}.jpg".format(count))
    cv2.imshow("gif",imgf)
    if cv2.waitKey(800) & 255 == ord("q"):
        break
    count=count+1
    if count==29:
        count=1
cv2.destroyAllWindows()

# %%
import imageio

# %%
imageio.mimsave(r"C:\Users\ADMIN\Downloads\PYTHON FILES\Open_CV\task\task2\i123.gif",[img0,img1,img2,img3,img4],fps=3)
